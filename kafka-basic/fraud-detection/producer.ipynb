# %%
from kafka import KafkaProducer
import json
import time
import random

producer = KafkaProducer(
    bootstrap_servers=['kafka:9092'],
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

user_ids = [101, 102, 103, 104, 105]

print("Starting Transaction Producer...")

for i in range(100):
    tx_data = {
        "tx_id": i,
        "userId": random.choice(user_ids),
        "amount": random.uniform(10.0, 15000.0), # >10000 triggers fraud
        "timestamp": time.time()
    }
    producer.send('fraud-detection', value=tx_data)
    print(f"Sent: {tx_data}")
    time.sleep(3)
# Out:
# Starting Transaction Producer...
# Sent: {'tx_id': 0, 'userId': 104, 'amount': 4944.955757689594, 'timestamp': 1781849671.152345}
# Sent: {'tx_id': 1, 'userId': 104, 'amount': 9888.1666729534, 'timestamp': 1781849674.2570627}
# Sent: {'tx_id': 2, 'userId': 104, 'amount': 4551.0978827290255, 'timestamp': 1781849677.2575917}
# Sent: {'tx_id': 3, 'userId': 103, 'amount': 7819.965275951771, 'timestamp': 1781849680.2648432}
# Sent: {'tx_id': 4, 'userId': 103, 'amount': 4841.754753667416, 'timestamp': 1781849683.2658854}
# Sent: {'tx_id': 5, 'userId': 104, 'amount': 766.6160785882654, 'timestamp': 1781849686.266496}
# Sent: {'tx_id': 6, 'userId': 105, 'amount': 461.6132331980007, 'timestamp': 1781849689.2670588}
# Sent: {'tx_id': 7, 'userId': 101, 'amount': 1145.9318622937067, 'timestamp': 1781849692.26754}
# Sent: {'tx_id': 8, 'userId': 104, 'amount': 10822.84027731771, 'timestamp': 1781849695.2681727}
# Sent: {'tx_id': 9, 'userId': 105, 'amount': 6207.269975519658, 'timestamp': 1781849698.2688015}
# Sent: {'tx_id': 10, 'userId': 105, 'amount': 8318.226847628319, 'timestamp': 1781849701.2705317}
# Sent: {'tx_id': 11, 'userId': 103, 'amount': 14300.50285390326, 'timestamp': 1781849704.270986}
# Sent: {'tx_id': 12, 'userId': 103, 'amount': 4069.9758118838176, 'timestamp': 1781849707.2722073}
# Sent: {'tx_id': 13, 'userId': 104, 'amount': 13822.383151264326, 'timestamp': 1781849710.2726657}
# Sent: {'tx_id': 14, 'userId': 103, 'amount': 446.42314901991097, 'timestamp': 1781849713.273111}
# Sent: {'tx_id': 15, 'userId': 103, 'amount': 13017.004152820142, 'timestamp': 1781849716.274396}
# Sent: {'tx_id': 16, 'userId': 103, 'amount': 5291.1269907296855, 'timestamp': 1781849719.2749217}
# Sent: {'tx_id': 17, 'userId': 105, 'amount': 12253.347551817802, 'timestamp': 1781849722.2753525}
# Sent: {'tx_id': 18, 'userId': 103, 'amount': 14833.280960681004, 'timestamp': 1781849725.2788906}
# Sent: {'tx_id': 19, 'userId': 104, 'amount': 11273.075875466082, 'timestamp': 1781849728.2801638}
# Sent: {'tx_id': 20, 'userId': 104, 'amount': 12168.649517998394, 'timestamp': 1781849731.2816637}
# Sent: {'tx_id': 21, 'userId': 102, 'amount': 13525.09184905127, 'timestamp': 1781849734.282034}
# Sent: {'tx_id': 22, 'userId': 105, 'amount': 6194.064439053879, 'timestamp': 1781849737.2833264}
# Sent: {'tx_id': 23, 'userId': 104, 'amount': 13407.920673805742, 'timestamp': 1781849740.2837915}
# Sent: {'tx_id': 24, 'userId': 105, 'amount': 2263.1367958622336, 'timestamp': 1781849743.2848215}
# Sent: {'tx_id': 25, 'userId': 102, 'amount': 11060.33685704076, 'timestamp': 1781849746.2852452}
# Sent: {'tx_id': 26, 'userId': 104, 'amount': 6656.6327867236405, 'timestamp': 1781849749.2858772}
# Sent: {'tx_id': 27, 'userId': 105, 'amount': 8486.120510489185, 'timestamp': 1781849752.2864575}
# Sent: {'tx_id': 28, 'userId': 104, 'amount': 12564.018905816818, 'timestamp': 1781849755.2877212}
# Sent: {'tx_id': 29, 'userId': 102, 'amount': 11722.120982275488, 'timestamp': 1781849758.2882903}
# Sent: {'tx_id': 30, 'userId': 104, 'amount': 4106.162903980455, 'timestamp': 1781849761.289561}
# Sent: {'tx_id': 31, 'userId': 103, 'amount': 7083.59593000298, 'timestamp': 1781849764.2905967}
# Sent: {'tx_id': 32, 'userId': 105, 'amount': 4121.734852273538, 'timestamp': 1781849767.291042}
# Sent: {'tx_id': 33, 'userId': 105, 'amount': 8701.329863808367, 'timestamp': 1781849770.2924993}
# Sent: {'tx_id': 34, 'userId': 104, 'amount': 12745.20056791806, 'timestamp': 1781849773.2930074}
# Sent: {'tx_id': 35, 'userId': 104, 'amount': 9872.325114561587, 'timestamp': 1781849776.2949462}
# Sent: {'tx_id': 36, 'userId': 103, 'amount': 3135.2097578167723, 'timestamp': 1781849779.2966595}
# Sent: {'tx_id': 37, 'userId': 102, 'amount': 711.3318077876482, 'timestamp': 1781849782.3007107}
# Sent: {'tx_id': 38, 'userId': 105, 'amount': 9805.6783927843, 'timestamp': 1781849785.3019578}
# Sent: {'tx_id': 39, 'userId': 101, 'amount': 12039.462660707111, 'timestamp': 1781849788.3025455}
# Sent: {'tx_id': 40, 'userId': 104, 'amount': 13315.471231610438, 'timestamp': 1781849791.304392}
# Sent: {'tx_id': 41, 'userId': 102, 'amount': 9732.960486227832, 'timestamp': 1781849794.305436}
# Sent: {'tx_id': 42, 'userId': 104, 'amount': 8769.94764318608, 'timestamp': 1781849797.3058813}
# Sent: {'tx_id': 43, 'userId': 103, 'amount': 9034.616947887565, 'timestamp': 1781849800.3062656}
# Sent: {'tx_id': 44, 'userId': 103, 'amount': 8453.695407938303, 'timestamp': 1781849803.3078334}
# Sent: {'tx_id': 45, 'userId': 102, 'amount': 3678.3309083319878, 'timestamp': 1781849806.309227}
# Sent: {'tx_id': 46, 'userId': 105, 'amount': 13126.171440898981, 'timestamp': 1781849809.310675}
# Sent: {'tx_id': 47, 'userId': 101, 'amount': 14065.769866682598, 'timestamp': 1781849812.311165}
# Sent: {'tx_id': 48, 'userId': 103, 'amount': 508.81037821661306, 'timestamp': 1781849815.312191}
# Sent: {'tx_id': 49, 'userId': 101, 'amount': 10762.033325286036, 'timestamp': 1781849818.3126302}
# Sent: {'tx_id': 50, 'userId': 103, 'amount': 7974.609566555596, 'timestamp': 1781849821.3139145}
# Sent: {'tx_id': 51, 'userId': 101, 'amount': 480.31460042960333, 'timestamp': 1781849824.3144078}
# Sent: {'tx_id': 52, 'userId': 104, 'amount': 14249.798024898795, 'timestamp': 1781849827.3148777}
# Sent: {'tx_id': 53, 'userId': 101, 'amount': 1687.3678999896388, 'timestamp': 1781849830.3170466}
# Sent: {'tx_id': 54, 'userId': 101, 'amount': 1402.7261158017836, 'timestamp': 1781849833.3193836}
# Sent: {'tx_id': 55, 'userId': 101, 'amount': 928.1774126521344, 'timestamp': 1781849836.319809}
# Sent: {'tx_id': 56, 'userId': 103, 'amount': 7410.335827310733, 'timestamp': 1781849839.320413}
# Sent: {'tx_id': 57, 'userId': 104, 'amount': 7246.71789056688, 'timestamp': 1781849842.3208537}
# Sent: {'tx_id': 58, 'userId': 103, 'amount': 9921.718281448142, 'timestamp': 1781849845.3222303}
# Sent: {'tx_id': 59, 'userId': 101, 'amount': 667.2519792650403, 'timestamp': 1781849848.32267}
# Sent: {'tx_id': 60, 'userId': 101, 'amount': 10945.786841586767, 'timestamp': 1781849851.3231485}
# Sent: {'tx_id': 61, 'userId': 104, 'amount': 12026.141430429128, 'timestamp': 1781849854.3235645}
# Sent: {'tx_id': 62, 'userId': 104, 'amount': 245.61777175772085, 'timestamp': 1781849857.3240507}
# Sent: {'tx_id': 63, 'userId': 103, 'amount': 1690.2029873942245, 'timestamp': 1781849860.3254118}
# Sent: {'tx_id': 64, 'userId': 105, 'amount': 8408.16431522424, 'timestamp': 1781849863.326048}
# Sent: {'tx_id': 65, 'userId': 102, 'amount': 5844.327528120378, 'timestamp': 1781849866.3271039}
# Sent: {'tx_id': 66, 'userId': 102, 'amount': 14167.734294940092, 'timestamp': 1781849869.3281426}
# Sent: {'tx_id': 67, 'userId': 105, 'amount': 14330.368703654236, 'timestamp': 1781849872.3300824}
# Sent: {'tx_id': 68, 'userId': 105, 'amount': 14880.113584861441, 'timestamp': 1781849875.3318715}
# Sent: {'tx_id': 69, 'userId': 102, 'amount': 2246.791094681415, 'timestamp': 1781849878.332292}
# Sent: {'tx_id': 70, 'userId': 102, 'amount': 12291.375620238672, 'timestamp': 1781849881.3328724}
# Sent: {'tx_id': 71, 'userId': 102, 'amount': 7870.941374551162, 'timestamp': 1781849884.3339388}
# Sent: {'tx_id': 72, 'userId': 104, 'amount': 310.3212041833724, 'timestamp': 1781849887.335173}
# Sent: {'tx_id': 73, 'userId': 101, 'amount': 6417.823031675057, 'timestamp': 1781849890.3355718}
# Sent: {'tx_id': 74, 'userId': 105, 'amount': 14837.950971992877, 'timestamp': 1781849893.336195}
# Sent: {'tx_id': 75, 'userId': 101, 'amount': 6238.265321826862, 'timestamp': 1781849896.337573}
# Sent: {'tx_id': 76, 'userId': 104, 'amount': 13153.246911096632, 'timestamp': 1781849899.339096}
# Sent: {'tx_id': 77, 'userId': 103, 'amount': 5184.7797756974405, 'timestamp': 1781849902.3396897}
# Sent: {'tx_id': 78, 'userId': 101, 'amount': 2952.012894814498, 'timestamp': 1781849905.3401327}
# Sent: {'tx_id': 79, 'userId': 101, 'amount': 2530.9651463779487, 'timestamp': 1781849908.3405755}
# Sent: {'tx_id': 80, 'userId': 101, 'amount': 601.0453791795924, 'timestamp': 1781849911.3427033}
# Sent: {'tx_id': 81, 'userId': 105, 'amount': 11903.50793265187, 'timestamp': 1781849914.3431814}
# Sent: {'tx_id': 82, 'userId': 104, 'amount': 14012.302418491408, 'timestamp': 1781849917.3436065}
# Sent: {'tx_id': 83, 'userId': 103, 'amount': 8825.679574664051, 'timestamp': 1781849920.3441436}
# Sent: {'tx_id': 84, 'userId': 102, 'amount': 8675.629390901684, 'timestamp': 1781849923.3446064}
# Sent: {'tx_id': 85, 'userId': 101, 'amount': 5877.658138670843, 'timestamp': 1781849926.3461497}
# Sent: {'tx_id': 86, 'userId': 102, 'amount': 9177.629816602584, 'timestamp': 1781849929.3488903}
# Sent: {'tx_id': 87, 'userId': 104, 'amount': 4535.6108526158605, 'timestamp': 1781849932.3683782}
# Sent: {'tx_id': 88, 'userId': 102, 'amount': 12823.06503161551, 'timestamp': 1781849935.3875852}
# Sent: {'tx_id': 89, 'userId': 104, 'amount': 4243.270338111893, 'timestamp': 1781849938.3891933}
# Sent: {'tx_id': 90, 'userId': 105, 'amount': 8841.031422823584, 'timestamp': 1781849941.3896687}
# Sent: {'tx_id': 91, 'userId': 102, 'amount': 5708.551114535168, 'timestamp': 1781849944.3903172}
# Sent: {'tx_id': 92, 'userId': 101, 'amount': 7024.808525902884, 'timestamp': 1781849947.3913248}
# Sent: {'tx_id': 93, 'userId': 101, 'amount': 2135.482316349207, 'timestamp': 1781849950.3919806}
# Sent: {'tx_id': 94, 'userId': 105, 'amount': 12833.891186396902, 'timestamp': 1781849953.3933842}
# Sent: {'tx_id': 95, 'userId': 104, 'amount': 1448.5375282837329, 'timestamp': 1781849956.3938408}
# Sent: {'tx_id': 96, 'userId': 101, 'amount': 14781.236527264507, 'timestamp': 1781849959.3951695}
# Sent: {'tx_id': 97, 'userId': 102, 'amount': 9295.24549070904, 'timestamp': 1781849962.3963344}
# Sent: {'tx_id': 98, 'userId': 105, 'amount': 13443.110216281844, 'timestamp': 1781849965.397532}
# Sent: {'tx_id': 99, 'userId': 103, 'amount': 2808.590198019786, 'timestamp': 1781849968.3982172}
